# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import pickle

# %%
from sklearn.neural_network import MLPClassifier

# %%
with open('credit.pkl', 'rb') as f:
    X_credit_treinamento, y_credit_treinamento, X_credit_teste, y_credit_teste = pickle.load(f)

# %%
rede_neural_credit = MLPClassifier(max_iter=1500, verbose=True, tol=0.0000100, solver='adam', activation='relu',hidden_layer_sizes=(100,100))
rede_neural_credit.fit(X_credit_treinamento, y_credit_treinamento)
# Out:
# Iteration 1, loss = 0.55983147
# Iteration 2, loss = 0.42400079
# Iteration 3, loss = 0.33879490
# Iteration 4, loss = 0.27204898
# Iteration 5, loss = 0.21795636
# Iteration 6, loss = 0.17708031
# Iteration 7, loss = 0.14796496
# Iteration 8, loss = 0.12806186
# Iteration 9, loss = 0.11404694
# Iteration 10, loss = 0.10360489
# Iteration 11, loss = 0.09547502
# Iteration 12, loss = 0.08907036
# Iteration 13, loss = 0.08349701
# Iteration 14, loss = 0.07865167
# Iteration 15, loss = 0.07403557
# Iteration 16, loss = 0.07012584
# Iteration 17, loss = 0.06611807
# Iteration 18, loss = 0.06268221
# Iteration 19, loss = 0.05929890
# Iteration 20, loss = 0.05608388
# Iteration 21, loss = 0.05371186
# Iteration 22, loss = 0.05010507
# Iteration 23, loss = 0.04823053
# Iteration 24, loss = 0.04580144
# Iteration 25, loss = 0.04349005
# Iteration 26, loss = 0.04132502
# Iteration 27, loss = 0.03987517
# Iteration 28, loss = 0.03770293
# Iteration 29, loss = 0.03667709
# Iteration 30, loss = 0.03496187
# Iteration 31, loss = 0.03366765
# Iteration 32, loss = 0.03228284
# Iteration 33, loss = 0.03132768
# Iteration 34, loss = 0.03022093
# Iteration 35, loss = 0.02947628
# Iteration 36, loss = 0.02825937
# Iteration 37, loss = 0.02734966
# Iteration 38, loss = 0.02660220
# Iteration 39, loss = 0.02587782
# Iteration 40, loss = 0.02504554
# Iteration 41, loss = 0.02444304
# Iteration 42, loss = 0.02389442
# Iteration 43, loss = 0.02324222
# Iteration 44, loss = 0.02281627
# Iteration 45, loss = 0.02210231
# Iteration 46, loss = 0.02155525
# Iteration 47, loss = 0.02069056
# Iteration 48, loss = 0.02046148
# Iteration 49, loss = 0.02021817
# Iteration 50, loss = 0.01961567
# Iteration 51, loss = 0.01945958
# Iteration 52, loss = 0.01828969
# Iteration 53, loss = 0.01849901
# Iteration 54, loss = 0.01787422
# Iteration 55, loss = 0.01743070
# Iteration 56, loss = 0.01696551
# Iteration 57, loss = 0.01674316
# Iteration 58, loss = 0.01634959
# Iteration 59, loss = 0.01611036
# Iteration 60, loss = 0.01585860
# Iteration 61, loss = 0.01558455
# Iteration 62, loss = 0.01571712
# Iteration 63, loss = 0.01520776
# Iteration 64, loss = 0.01549257
# Iteration 65, loss = 0.01499320
# Iteration 66, loss = 0.01468836
# Iteration 67, loss = 0.01460036
# Iteration 224, loss = 0.00286231
# Iteration 225, loss = 0.00304576
# Iteration 226, loss = 0.00306252
# Iteration 227, loss = 0.00275026
# Iteration 228, loss = 0.00265589
# Iteration 229, loss = 0.00288776
# Iteration 230, loss = 0.00294909
# Iteration 231, loss = 0.00325776
# Iteration 232, loss = 0.00281994
# Iteration 233, loss = 0.00308741
# Iteration 234, loss = 0.00314548
# Iteration 235, loss = 0.00280555
# Iteration 236, loss = 0.00275063
# Iteration 237, loss = 0.00319652
# Iteration 238, loss = 0.00290766
# Iteration 239, loss = 0.00235466
# Iteration 240, loss = 0.00279482
# Iteration 241, loss = 0.00239379
# Iteration 242, loss = 0.00246993
# Iteration 243, loss = 0.00243272
# Iteration 244, loss = 0.00255672
# Iteration 245, loss = 0.00238861
# Iteration 246, loss = 0.00240226
# Iteration 247, loss = 0.00231295
# Iteration 248, loss = 0.00249734
# Iteration 249, loss = 0.00224941
# Iteration 250, loss = 0.00252992
# Iteration 251, loss = 0.00263949
# Iteration 252, loss = 0.00232465
# Iteration 253, loss = 0.00234720
# Iteration 254, loss = 0.00223645
# Iteration 255, loss = 0.00234896
# Iteration 256, loss = 0.00228212
# Iteration 257, loss = 0.00232188
# Iteration 258, loss = 0.00213047
# Iteration 259, loss = 0.00230945
# Iteration 260, loss = 0.00286678
# Iteration 261, loss = 0.00219217
# Iteration 262, loss = 0.00229346
# Iteration 263, loss = 0.00213439
# Iteration 264, loss = 0.00233268
# Iteration 265, loss = 0.00234430
# Iteration 266, loss = 0.00228184
# Iteration 267, loss = 0.00224833
# Iteration 268, loss = 0.00218976
# Iteration 269, loss = 0.00230328
# Training loss did not improve more than tol=0.000010 for 10 consecutive epochs. Stopping.
# MLPClassifier(hidden_layer_sizes=(100, 100), max_iter=1500, tol=1e-05,
#               verbose=True)

# %%
previsoes = rede_neural_credit.predict(X_credit_teste)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
accuracy_score(y_credit_teste, previsoes)
# Out:
# 0.996

# %%
confusion_matrix(y_credit_teste, previsoes)
# Out:
# array([[435,   1],
#        [  1,  63]], dtype=int64)

# %%
print(classification_report(y_credit_teste, previsoes))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       436
#            1       0.98      0.98      0.98        64
#
#     accuracy                           1.00       500
#    macro avg       0.99      0.99      0.99       500
# weighted avg       1.00      1.00      1.00       500

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import NuSVC
from sklearn.neural_network import MLPClassifier

# %%
X_credit = np.concatenate((X_credit_treinamento, X_credit_teste), axis = 0)
y_credit = np.concatenate((y_credit_treinamento, y_credit_teste), axis=0)

# %%
parametros = {
    'activation': ['relu', 'logistic', 'tanh'],
    'solver': ['adam', 'sgd'],
    'batch_size': [10, 56]
}

# %%
grid_search = GridSearchCV(estimator = MLPClassifier(), param_grid=parametros)
grid_search.fit(X_credit, y_credit)
melhores_parametros = grid_search.best_params_
melhor_resultado = grid_search.best_score_
# Out:
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\eliaq\anaconda3\envs\machine_learning_data_science01\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
print(melhores_parametros)
print(melhor_resultado)
# Out:
# {'activation': 'relu', 'batch_size': 56, 'solver': 'adam'}
# 0.9964999999999999
